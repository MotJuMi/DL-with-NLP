# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index

  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)

  span = 2 * skip_window + 1
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

  for i in range(batch_size):
    labels[i] = buffer[bag_window] # target
    batch[i] = list(buffer)[: bag_window] + list(buffer)[bag_window + 1:] # context
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %% [markdown]
# Train a CBOW model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
#num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_mean(tf.nn.embedding_lookup(embeddings, train_dataset), 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, bag_window)
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-41-65bb22c92bc9>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.112000
# Nearest to called: mccay, fined, bolshevism, aegean, enhancing, valine, week, wieman,
# Nearest to to: lisboa, fitna, omniscience, winnings, oswald, morgue, arians, urchin,
# Nearest to over: studies, electrodes, dryness, manually, mcclellan, redistribution, fabricius, realizing,
# Nearest to nine: destructive, congreso, hydrofoils, weighting, gatehouse, restructure, eyeball, dm,
# Nearest to other: icd, zf, importantly, impaled, bursa, ducktales, harshness, lac,
# Nearest to who: muscles, worry, imitation, yerushalayim, reisman, redemption, gauze, ironworks,
# Nearest to zero: wiktionary, interconnect, clem, bsp, cladogram, bug, filk, appreciate,
# Nearest to th: ambulatory, hur, pun, injections, parenting, windmills, mommy, instrumentals,
# Nearest to years: fleury, separatist, iridium, bosnian, wakko, transclusion, namesake, dashiell,
# Nearest to with: pips, prat, processed, educators, webpages, rnir, negro, rdenas,
# Nearest to not: qq, haggard, menthol, evaluates, asp, mexicana, devoured, type,
# Nearest to up: multihull, burman, var, shalom, tint, lombard, sport, osiris,
# Nearest to and: fantagraphics, lycia, intolerance, sperry, dien, middletown, accepts, winthrop,
# Nearest to when: justifiable, fall, cheerfully, moroccans, exploratory, nuclear, frequent, fulham,
# Nearest to some: jakob, infield, mol, motivates, conceptualized, fon, united, freyja,
# Nearest to the: ultrasound, curie, questions, annexed, interprets, bambino, disposition, transitive,
# Average loss at step 2000: 4.120437
# Average loss at step 4000: 3.619604
# Average loss at step 6000: 3.464555
# Average loss at step 8000: 3.299385
# Average loss at step 10000: 3.291806
# Nearest to called: aegean, website, parentheses, mccay, bolshevism, niue, enhancing, rockin,
# Nearest to to: could, winnings, cove, into, couper, urchin, feud, rainforests,
# Nearest to over: pled, studies, dryness, fiercest, manually, cassette, consonances, amused,
# Nearest to nine: eight, seven, zero, six, lacanian, drowning, rca, apollo,
# Nearest to other: tractate, packs, some, stamford, inquisitorial, impaled, tardis, krone,
# Nearest to who: he, rafik, rcn, worry, muscles, yerushalayim, theorem, asphyxia,
# Nearest to zero: eight, nine, three, five, six, four, seven, comprehensive,
# Nearest to th: rigorously, instrumentals, windmills, hur, injections, mommy, failures, ancestral,
# Nearest to years: fleury, separatist, austrians, dashiell, transclusion, nitrogen, cases, lizzie,
# Nearest to with: prat, educators, few, webpages, pura, stamford, otranto, howlin,
# Nearest to not: recursively, they, canter, achievements, statehood, icmp, it, anticipating,
# Nearest to up: multihull, newcastle, tint, them, louvre, exogenous, steamships, shoot,
# Nearest to and: or, bridle, lublin, subsidence, roberta, but, skating, sperry,
# Nearest to when: cheerfully, against, justifiable, encoders, exploratory, colorful, tripoli, cryptography,
# Nearest to some: many, her, other, ghettos, systems, conceptualized, derby, antilles,
# Nearest to the: any, its, this, their, a, robo, an, pundits,
# Average loss at step 12000: 3.308017
# Average loss at step 14000: 3.276101
# Average loss at step 16000: 3.282656
# Average loss at step 18000: 3.257175
# Average loss at step 20000: 3.124831
# Nearest to called: aegean, website, parentheses, rockin, madame, bolshevism, week, props,
# Nearest to to: will, could, would, may, bette, winnings, loch, stuka,
# Nearest to over: dryness, pled, studies, datura, fiercest, since, rulemaking, autoerotic,
# Nearest to nine: eight, seven, zero, lacanian, six, five, september, october,
# Nearest to other: krone, packs, tractate, inquisitorial, impaled, stamford, tardis, menace,
# Nearest to who: he, jolie, rcn, rafik, yerushalayim, asphyxia, worry, sava,
# Nearest to zero: eight, five, seven, nine, six, three, four, pessimistic,
# Nearest to th: rigorously, instrumentals, hur, nine, failures, mommy, airforce, windmills,
# Nearest to years: separatist, fleury, days, austrians, period, dashiell, nitrogen, transclusion,
# Nearest to with: prat, capped, howlin, educators, objective, headquarters, otranto, webpages,
# Nearest to not: recursively, canter, icmp, devoured, they, achievements, statehood, ducks,
# Nearest to up: them, tint, multihull, louvre, shoot, steamships, exogenous, burman,
# Nearest to and: or, but, bridle, roberta, lilith, hannibal, hurdle, because,
# Nearest to when: against, cheerfully, justifiable, if, where, encoders, exploratory, crassus,
# Nearest to some: many, several, various, systems, jona, derby, ghettos, trainees,
# Nearest to the: their, a, any, its, his, dtft, derbyshire, each,
# Average loss at step 22000: 3.220171
# Average loss at step 24000: 3.177362
# Average loss at step 26000: 3.153031
# Average loss at step 28000: 3.178098
# Average loss at step 30000: 3.130496
# Nearest to called: aegean, parentheses, website, used, known, mss, madame, poetic,
# Nearest to to: will, would, could, may, should, can, must, stuka,
# Nearest to over: datura, fiercest, rulemaking, autoerotic, since, perhaps, pled, dryness,
# Nearest to nine: eight, seven, six, zero, late, drowning, four, five,
# Nearest to other: krone, inquisitorial, different, connolly, tractate, tardis, various, these,
# Nearest to who: he, jolie, yerushalayim, rcn, sava, asphyxia, worry, landsat,
# Nearest to zero: five, eight, six, million, nd, nine, four, seven,
# Nearest to th: rigorously, instrumentals, hur, nine, mommy, sawdust, failures, airforce,
# Nearest to years: days, fleury, separatist, period, months, nitrogen, austrians, year,
# Nearest to with: prat, capped, contains, howlin, otranto, reply, rdenas, voluntarily,
# Nearest to not: recursively, devoured, icmp, canter, ducks, statehood, almost, madhya,
# Nearest to up: them, tint, out, back, multihull, down, steamships, bicycling,
# Nearest to and: or, but, including, while, inclusions, bridle, reputations, altenberg,
# Nearest to when: against, if, cheerfully, where, crassus, justifiable, encoders, retailer,
# Nearest to some: many, various, several, most, derby, all, jona, passing,
# Nearest to the: its, their, tectonics, a, illuminism, extortion, retires, porous,
# Average loss at step 32000: 2.976150
# Average loss at step 34000: 3.110540
# Average loss at step 36000: 3.099421
# Average loss at step 38000: 3.059575
# Average loss at step 40000: 3.078550
# Nearest to called: parentheses, aegean, used, known, website, madame, considered, tennant,
# Nearest to to: will, would, could, may, bette, should, stuka, must,
# Nearest to over: rulemaking, datura, fiercest, beyond, embodied, perhaps, pled, dryness,
# Nearest to nine: eight, seven, six, five, late, lacanian, facet, rca,
# Nearest to other: various, inquisitorial, these, connolly, different, krone, some, chancellery,
# Nearest to who: he, jolie, sava, yerushalayim, rcn, purging, landsat, averted,
# Nearest to zero: five, six, eight, seven, four, three, million, nd,
# Nearest to th: twentieth, rigorously, nd, hur, eight, instrumentals, sawdust, mommy,
# Nearest to years: days, months, period, fleury, year, austrians, nitrogen, dashiell,
# Nearest to with: howlin, episcopi, prat, capped, musab, barcode, reply, otranto,
# Nearest to not: icmp, recursively, ducks, canter, sibley, madhya, statehood, devoured,
# Nearest to up: out, them, down, tint, back, multihull, trojans, steamships,
# Nearest to and: or, including, but, operand, while, stud, bolger, dilemmas,
# Nearest to when: if, because, against, where, crassus, encoders, though, retailer,
# Nearest to some: many, various, several, most, derby, all, passing, other,
# Nearest to the: their, any, its, a, wyoming, tectonics, this, retires,
# Average loss at step 42000: 3.108019
# Average loss at step 44000: 3.064915
# Average loss at step 46000: 3.075619
# Average loss at step 48000: 3.002902
# Average loss at step 50000: 2.991419
# Nearest to called: used, parentheses, known, aegean, considered, madame, poetic, tennant,
# Nearest to to: will, would, could, towards, should, bette, morgue, must,
# Nearest to over: rulemaking, beyond, datura, fiercest, pled, away, embodied, dryness,
# Nearest to nine: eight, seven, six, march, lacanian, five, drowning, september,
# Nearest to other: various, these, inquisitorial, different, krone, connolly, witold, salient,
# Nearest to who: he, jolie, yerushalayim, sava, young, notoriety, worry, rcn,
# Nearest to zero: eight, five, seven, six, four, three, bce, nine,
# Nearest to th: nd, twentieth, rigorously, st, mommy, sawdust, eight, hur,
# Nearest to years: days, months, period, year, austrians, fleury, minutes, valet,
# Nearest to with: prat, rdenas, capped, howlin, between, contains, voluntarily, episcopi,
# Nearest to not: icmp, recursively, canter, sibley, ducks, never, almost, rarely,
# Nearest to up: out, down, tint, back, them, bicycling, trojans, steamships,
# Nearest to and: or, including, while, but, skating, operand, tearing, bolger,
# Nearest to when: if, because, where, against, while, though, crassus, before,
# Nearest to some: many, several, various, most, derby, all, certain, multiple,
# Nearest to the: its, their, a, our, tectonics, dtft, his, slovakian,
# Average loss at step 52000: 3.019721
# Average loss at step 54000: 3.032277
# Average loss at step 56000: 2.888593
# Average loss at step 58000: 2.978942
# Average loss at step 60000: 2.996406
# Nearest to called: considered, used, parentheses, known, madame, poetic, spider, named,
# Nearest to to: will, would, could, morgue, towards, should, must, ibiza,
# Nearest to over: rulemaking, beyond, datura, toward, fiercest, dryness, cassette, incipient,
# Nearest to nine: eight, seven, six, five, zero, late, march, lacanian,
# Nearest to other: various, these, inquisitorial, different, krone, connolly, importantly, chancellery,
# Nearest to who: he, jolie, young, yerushalayim, notoriety, landsat, worry, sava,
# Nearest to zero: five, eight, seven, six, four, nine, million, three,
# Nearest to th: nd, twentieth, rigorously, sawdust, mommy, instrumentals, st, hur,
# Nearest to years: days, months, decades, minutes, period, fleury, year, austrians,
# Nearest to with: prat, rdenas, between, musab, gottes, howlin, capped, kaufmann,
# Nearest to not: canter, sibley, almost, recursively, rarely, icmp, ducks, never,
# Nearest to up: out, down, back, tint, bicycling, off, them, trojans,
# Nearest to and: or, but, while, antidepressants, asahi, operand, bolger, however,
# Nearest to when: if, because, where, against, though, while, before, although,
# Nearest to some: many, several, various, most, derby, all, multiple, certain,
# Nearest to the: its, their, dtft, exhaustion, hash, refracting, retires, appalachia,
# Average loss at step 62000: 2.961038
# Average loss at step 64000: 2.887918
# Average loss at step 66000: 2.888286
# Average loss at step 68000: 2.886179
# Average loss at step 70000: 2.957149
# Nearest to called: considered, parentheses, known, named, poetic, spider, used, tennant,
# Nearest to to: will, could, would, should, must, stuka, might, towards,
# Nearest to over: rulemaking, beyond, dryness, fiercest, away, cassette, embodied, datura,
# Nearest to nine: eight, seven, lacanian, march, billion, late, drowning, ca,
# Nearest to other: various, these, inquisitorial, different, krone, connolly, chancellery, impaled,
# Nearest to who: he, young, jolie, landsat, yerushalayim, notoriety, sava, nietzsche,
# Nearest to zero: five, six, seven, eight, three, two, cuneiform, four,
# Nearest to th: nd, twentieth, rigorously, st, mommy, sawdust, instrumentals, rd,
# Nearest to years: days, months, decades, minutes, year, period, austrians, fleury,
# Nearest to with: prat, voluntarily, rdenas, barcode, eurydice, capped, musab, between,
# Nearest to not: rarely, never, sibley, almost, still, icmp, ducks, recursively,
# Nearest to up: out, down, back, off, tint, bicycling, trojans, them,
# Nearest to and: or, while, including, operand, but, dubliners, bolger, asahi,
# Nearest to when: if, because, where, against, before, though, while, cameron,
# Nearest to some: many, various, several, most, all, certain, derby, multiple,
# Nearest to the: its, their, a, retires, infraorder, our, azrael, thousands,
# Average loss at step 72000: 2.905968
# Average loss at step 74000: 2.842761
# Average loss at step 76000: 2.953392
# Average loss at step 78000: 2.962342
# Average loss at step 80000: 2.826271
# Nearest to called: considered, named, used, parentheses, spider, poetic, known, tennant,
# Nearest to to: will, would, could, towards, should, might, must, stuka,
# Nearest to over: rulemaking, beyond, cassette, aperture, embodied, throughout, fiercest, phosphate,
# Nearest to nine: eight, seven, six, zero, lacanian, late, march, september,
# Nearest to other: various, these, inquisitorial, different, krone, connolly, individual, including,
# Nearest to who: he, jolie, young, landsat, sava, yerushalayim, notoriety, rcn,
# Nearest to zero: five, six, seven, eight, million, four, nine, three,
# Nearest to th: nd, twentieth, st, sawdust, rigorously, nine, instrumentals, mommy,
# Nearest to years: months, days, decades, minutes, year, hours, weeks, austrians,
# Nearest to with: between, rdenas, capped, give, barcode, gottes, voluntarily, prat,
# Nearest to not: rarely, never, sibley, icmp, almost, still, ducks, canceled,
# Nearest to up: out, down, off, back, tint, trojans, bicycling, aside,
# Nearest to and: or, while, including, asahi, operand, but, typesetting, untrue,
# Nearest to when: if, because, where, before, though, while, against, cameron,
# Nearest to some: many, various, several, most, certain, all, multiple, derby,
# Nearest to the: its, our, their, tectonics, a, capable, infraorder, appalachia,
# Average loss at step 82000: 2.911537
# Average loss at step 84000: 2.874244
# Average loss at step 86000: 2.894832
# Average loss at step 88000: 2.920683
# Average loss at step 90000: 2.811397
# Nearest to called: considered, named, used, known, spider, poetic, tennant, parentheses,
# Nearest to to: will, would, should, towards, could, might, must, may,
# Nearest to over: rulemaking, beyond, cassette, fiercest, throughout, around, phosphate, aperture,
# Nearest to nine: eight, seven, six, zero, late, lacanian, four, drowning,
# Nearest to other: these, inquisitorial, various, different, krone, connolly, chancellery, individual,
# Nearest to who: he, landsat, yerushalayim, young, deleted, sava, jolie, cheques,
# Nearest to zero: eight, five, seven, six, four, nine, million, conjunct,
# Nearest to th: nd, twentieth, st, sawdust, rigorously, rd, nine, bills,
# Nearest to years: months, days, decades, minutes, hours, year, weeks, austrians,
# Nearest to with: between, rdenas, musab, barcode, give, howlin, loathed, prat,
# Nearest to not: rarely, never, almost, sibley, still, icmp, reproduced, ducks,
# Nearest to up: out, down, off, back, bicycling, aside, trojans, tint,
# Nearest to and: or, while, operand, including, asahi, disparity, antidepressants, but,
# Nearest to when: if, because, where, while, though, before, cameron, against,
# Nearest to some: many, various, several, most, both, certain, multiple, all,
# Nearest to the: its, our, retires, another, unquestioned, greyhound, any, a,
# Average loss at step 92000: 2.860814
# Average loss at step 94000: 2.863263
# Average loss at step 96000: 2.697762
# Average loss at step 98000: 2.480226
# Average loss at step 100000: 2.689454
# Nearest to called: named, considered, used, known, spider, poetic, tennant, derwent,
# Nearest to to: would, will, towards, should, could, must, might, morgue,
# Nearest to over: rulemaking, beyond, cassette, around, throughout, fiercest, phosphate, away,
# Nearest to nine: eight, seven, six, five, zero, lacanian, vf, four,
# Nearest to other: inquisitorial, these, various, different, others, individual, connolly, including,
# Nearest to who: yerushalayim, he, whom, young, landsat, deleted, sava, jolie,
# Nearest to zero: five, seven, eight, six, four, nine, million, three,
# Nearest to th: nd, twentieth, rd, st, rigorously, sawdust, mommy, instrumentals,
# Nearest to years: months, days, decades, year, weeks, hours, minutes, austrians,
# Nearest to with: give, rdenas, between, musab, kaufmann, gottes, barcode, scenic,
# Nearest to not: rarely, never, nothing, almost, icmp, sibley, ducks, litters,
# Nearest to up: out, down, off, back, trojans, bicycling, together, aside,
# Nearest to and: or, but, while, operand, including, antidepressants, untrue, fragrance,
# Nearest to when: if, because, where, while, before, though, although, instead,
# Nearest to some: many, various, several, most, both, multiple, certain, all,
# Nearest to the: our, dirichlet, unquestioned, its, a, tectonics, capri, their,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
#num_skips = 4 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, bag_window)
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-45-65bb22c92bc9>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.996629
# Nearest to up: polygonal, sought, erbium, notches, rpg, maladaptive, sidewinder, proceeds,
# Nearest to between: unconsciously, disintegration, sin, codebreakers, externalization, dialectal, rebelling, talisman,
# Nearest to b: sonata, biblical, dine, manuals, stratton, colonised, monument, overlying,
# Nearest to history: dil, buckets, macroeconomics, hubs, azali, enemies, venetia, insurrection,
# Nearest to two: eurosceptics, gu, simplifies, bukhari, acculturation, ola, gleaming, stratigraphic,
# Nearest to war: schoolteacher, britannicus, smoothing, tracy, scrambled, freelance, totals, puppets,
# Nearest to during: baby, pulp, avoids, olympic, whereas, hyman, irresistible, appendix,
# Nearest to but: concede, trilled, trampled, assented, nami, voyager, michelle, contextual,
# Nearest to his: hermitage, olmec, romanized, longrightarrow, felines, futures, niches, hinder,
# Nearest to these: restroom, angered, henchmen, lensing, solely, dipping, clock, ripple,
# Nearest to than: ron, oint, stall, schemes, spada, begs, colourful, liquid,
# Nearest to one: humayun, ats, pli, scratching, nonviolent, constituent, mckellen, quell,
# Nearest to use: domesticated, finnegans, humiliated, monster, auspices, tactical, refuges, zeist,
# Nearest to that: dbv, kondratiev, isaurian, rewarding, cin, implicated, busing, sebastian,
# Nearest to can: rib, touches, brief, ichthyology, archelaus, carry, ecclestone, ballast,
# Nearest to th: vest, cleanly, pythagoras, barrington, signalling, reintegrated, schwarzenegger, dreary,
# Average loss at step 2000: 4.483961
# Average loss at step 4000: 3.879673
# Average loss at step 6000: 3.786864
# Average loss at step 8000: 3.613000
# Average loss at step 10000: 3.603644
# Nearest to up: sidewinder, eraser, cancellation, him, fiefs, printing, zbigniew, sought,
# Nearest to between: unconsciously, freeport, disintegration, with, dialectal, alderney, acceptable, alimony,
# Nearest to b: malabar, monument, price, selznick, attended, biblical, mtp, interbreeding,
# Nearest to history: possibility, dermatology, venetia, apprenticed, lagrand, clerical, clich, list,
# Nearest to two: five, four, six, three, breaded, smokey, juliana, cavan,
# Nearest to war: vociferous, childe, bottlenecks, ayya, jubilee, braves, hosni, biqa,
# Nearest to during: in, before, over, after, at, jimi, alhazen, crocker,
# Nearest to but: and, however, antimatter, micron, while, than, played, invisibility,
# Nearest to his: her, its, their, the, dunant, s, budo, inv,
# Nearest to these: some, many, all, those, maduro, bp, both, there,
# Nearest to than: truthful, or, but, peck, chu, franchised, schemes, liquid,
# Nearest to one: patria, ascending, christiaan, hosting, tarquinius, aspen, underestimate, playfulness,
# Nearest to use: fashions, thulsa, lasor, cogent, motion, cedilla, open, deteriorate,
# Nearest to that: which, engendered, when, bioko, what, verified, database, this,
# Nearest to can: may, will, would, could, must, should, cannot, cet,
# Nearest to th: nine, unimaginable, kittyhawk, vsl, blige, cleanly, bakersfield, er,
# Average loss at step 12000: 3.560920
# Average loss at step 14000: 3.549024
# Average loss at step 16000: 3.382202
# Average loss at step 18000: 3.165387
# Average loss at step 20000: 3.230966
# Nearest to up: off, out, gradually, them, cancellation, him, down, mineralogist,
# Nearest to between: with, alimony, alderney, within, freeport, during, boost, acceptable,
# Nearest to b: d, doings, vaduz, disorganized, cossack, mcgill, reformists, linden,
# Nearest to history: grasso, series, clerical, disagree, buch, study, delle, lis,
# Nearest to two: three, zero, four, six, five, nine, seven, eight,
# Nearest to war: bottlenecks, melt, childe, airships, braves, law, vociferous, border,
# Nearest to during: in, before, after, within, however, over, under, against,
# Nearest to but: than, or, while, however, gently, dishonesty, locates, and,
# Nearest to his: her, their, its, the, seti, my, s, cois,
# Nearest to these: many, all, other, various, several, multiple, those, the,
# Nearest to than: but, or, strives, recently, lulach, truthful, josip, remarque,
# Nearest to one: handy, accesses, logitech, manchus, masoretic, trilled, despotism, mathilde,
# Nearest to use: produce, badges, work, exist, lahr, change, way, loads,
# Nearest to that: which, corwin, electrophysiology, engendered, quarantine, who, staley, garz,
# Nearest to can: will, could, would, may, should, must, cannot, might,
# Nearest to th: kittyhawk, unimaginable, twentieth, st, cleanly, er, beards, blige,
# Average loss at step 22000: 3.378460
# Average loss at step 24000: 3.244072
# Average loss at step 26000: 3.252681
# Average loss at step 28000: 3.322489
# Average loss at step 30000: 3.208891
# Nearest to up: off, down, out, him, back, them, controls, gradually,
# Nearest to between: within, alimony, with, freeport, alderney, among, thus, connotations,
# Nearest to b: d, itt, disorganized, ilois, foundry, weakens, hieronymus, steering,
# Nearest to history: life, wilder, style, development, duvall, terms, purcell, hamadan,
# Nearest to two: three, five, four, sancti, six, kite, terms, unravel,
# Nearest to war: bottlenecks, vociferous, stumbling, cathay, melt, lech, martina, braves,
# Nearest to during: after, in, until, before, since, throughout, over, at,
# Nearest to but: than, schiff, and, lattice, butch, however, scalar, see,
# Nearest to his: her, their, its, the, my, your, our, whose,
# Nearest to these: various, different, several, many, other, those, all, their,
# Nearest to than: but, recently, while, remarque, overstated, prescriptions, or, jodie,
# Nearest to one: seven, eight, resigning, hosting, pronged, nine, selwyn, nonpartisan,
# Nearest to use: produce, form, remains, sense, account, progresses, motion, autographs,
# Nearest to that: which, where, staley, who, because, however, when, while,
# Nearest to can: could, may, would, must, will, should, cannot, shall,
# Nearest to th: st, nine, twentieth, rd, beards, kittyhawk, nd, ambedkar,
# Average loss at step 32000: 3.177832
# Average loss at step 34000: 3.159509
# Average loss at step 36000: 3.076564
# Average loss at step 38000: 3.096440
# Average loss at step 40000: 3.109953
# Nearest to up: off, down, them, him, back, controls, rise, together,
# Nearest to between: within, with, connotations, through, alimony, across, thus, alderney,
# Nearest to b: d, vail, tats, outcasts, conjugations, receipt, enterprising, hypersonic,
# Nearest to history: wilder, development, study, list, life, origin, philosophy, description,
# Nearest to two: four, three, five, zero, six, seven, nine, eight,
# Nearest to war: bottlenecks, lech, manga, variability, rockstar, around, erin, bohdan,
# Nearest to during: before, after, until, since, in, throughout, over, despite,
# Nearest to but: however, though, and, although, which, radiosity, lattice, ffffff,
# Nearest to his: her, their, its, my, the, whose, our, your,
# Nearest to these: several, willis, different, multiple, other, various, certain, which,
# Nearest to than: or, recently, while, overstated, mega, yorkers, strives, sleeves,
# Nearest to one: calcite, ifad, macanese, starches, vci, lp, dst, pronged,
# Nearest to use: produce, form, accompanies, unsubstantiated, make, result, support, archers,
# Nearest to that: which, where, what, when, this, who, because, sentience,
# Nearest to can: must, could, may, should, will, might, would, cannot,
# Nearest to th: st, nd, twentieth, beards, nineteenth, eight, blige, spoofs,
# Average loss at step 42000: 3.099749
# Average loss at step 44000: 3.138292
# Average loss at step 46000: 3.093946
# Average loss at step 48000: 2.975763
# Average loss at step 50000: 3.100585
# Nearest to up: out, off, together, down, back, sylvester, them, kis,
# Nearest to between: with, within, across, alderney, hani, hornet, alimony, thus,
# Nearest to b: d, f, r, uu, wigner, k, pharmacology, carvalho,
# Nearest to history: origins, factoring, nipple, afar, development, unaccompanied, skits, temple,
# Nearest to two: four, three, five, eight, one, zero, six, many,
# Nearest to war: wars, bottlenecks, martina, cathay, emperors, smolensk, lech, tdi,
# Nearest to during: throughout, in, after, before, within, under, since, despite,
# Nearest to but: however, although, and, though, while, because, envision, where,
# Nearest to his: her, their, its, the, my, s, your, our,
# Nearest to these: various, several, multiple, certain, many, different, numerous, some,
# Nearest to than: or, but, mega, prescriptions, overstated, josip, novoselic, like,
# Nearest to one: two, eight, disestablished, order, seven, giver, late, michaux,
# Nearest to use: form, produce, version, usage, sense, because, jiao, peck,
# Nearest to that: which, what, because, where, if, staley, how, however,
# Nearest to can: must, could, may, will, should, cannot, might, would,
# Nearest to th: st, nd, twentieth, nineteenth, blige, computations, rd, nine,
# Average loss at step 52000: 3.078044
# Average loss at step 54000: 3.068007
# Average loss at step 56000: 3.081004
# Average loss at step 58000: 3.012704
# Average loss at step 60000: 2.837449
# Nearest to up: down, off, out, together, back, rambling, gradually, them,
# Nearest to between: with, among, hornet, alderney, across, therefore, within, against,
# Nearest to b: p, r, d, relapsed, k, l, grue, elihu,
# Nearest to history: period, philosophy, map, origin, mongols, medieval, tops, origins,
# Nearest to two: three, four, zero, several, various, hanno, juliana, alkaline,
# Nearest to war: wars, bottlenecks, cathay, tdi, mustafa, period, campaign, vociferous,
# Nearest to during: throughout, after, before, in, since, despite, until, from,
# Nearest to but: however, although, though, and, guis, yet, while, gleichschaltung,
# Nearest to his: her, their, its, my, the, our, your, whose,
# Nearest to these: certain, multiple, specific, some, various, different, those, other,
# Nearest to than: overstated, much, recently, prescriptions, or, mega, kilogram, moveable,
# Nearest to one: ratchet, modell, cryptozoologists, declassified, screech, craps, emf, fleischer,
# Nearest to use: sense, form, usage, jiao, addition, version, synthesis, because,
# Nearest to that: which, what, however, when, where, how, this, whom,
# Nearest to can: must, may, could, might, cannot, should, would, will,
# Nearest to th: st, nd, twentieth, computations, rd, nineteenth, nine, beards,
# Average loss at step 62000: 3.027765
# Average loss at step 64000: 3.020866
# Average loss at step 66000: 3.055506
# Average loss at step 68000: 3.041231
# Average loss at step 70000: 3.066236
# Nearest to up: off, down, out, gradually, sylvester, kis, rambling, composes,
# Nearest to between: with, among, alderney, within, tonga, from, hornet, cabrera,
# Nearest to b: d, c, drawback, p, x, pharmacology, rabbit, cronje,
# Nearest to history: origin, life, origins, philosophy, period, medieval, skits, wilder,
# Nearest to two: three, five, eight, four, juliana, several, six, opencyc,
# Nearest to war: wars, martina, bottlenecks, tdi, lech, campaign, heritage, smolensk,
# Nearest to during: throughout, before, since, after, in, over, until, through,
# Nearest to but: although, however, though, and, than, who, gently, see,
# Nearest to his: her, their, its, my, your, our, zahir, scofield,
# Nearest to these: various, several, certain, multiple, different, specific, winger, grocery,
# Nearest to than: but, or, chu, executables, while, melodramatic, snl, kilogram,
# Nearest to one: cryptozoologists, five, thulsa, jehoash, three, tokyo, zach, manchus,
# Nearest to use: version, sense, because, list, justin, descendants, produce, degenerative,
# Nearest to that: which, where, although, however, dicots, when, because, unless,
# Nearest to can: could, must, may, cannot, will, should, would, might,
# Nearest to th: st, nd, twentieth, rd, sixth, nine, nineteenth, naively,
# Average loss at step 72000: 3.010345
# Average loss at step 74000: 3.023934
# Average loss at step 76000: 2.927687
# Average loss at step 78000: 2.933174
# Average loss at step 80000: 2.993368
# Nearest to up: off, out, surfaces, kis, down, him, decided, together,
# Nearest to between: with, thus, among, tonga, alderney, into, through, across,
# Nearest to b: d, dagbladet, bribed, savior, precision, meaningful, selberg, episcopalians,
# Nearest to history: origins, list, origin, nature, ketchup, life, exporter, obrenovi,
# Nearest to two: three, zhao, sopra, plating, megalithic, jebel, jeter, one,
# Nearest to war: wars, bottlenecks, attack, martina, struggle, tdi, weather, heritage,
# Nearest to during: throughout, in, before, since, after, through, following, within,
# Nearest to but: although, though, than, however, while, and, fg, until,
# Nearest to his: their, her, its, your, my, our, the, s,
# Nearest to these: various, certain, all, multiple, different, other, several, numerous,
# Nearest to than: or, but, unlike, executables, like, recently, while, likely,
# Nearest to one: situs, roaming, masoretic, manchus, biota, thulsa, handy, elisabetta,
# Nearest to use: exist, archeology, thumbnail, sense, because, version, return, regrettable,
# Nearest to that: which, how, where, what, although, however, because, when,
# Nearest to can: could, must, should, may, cannot, might, would, will,
# Nearest to th: nd, twentieth, rd, st, nine, nineteenth, sixth, third,
# Average loss at step 82000: 2.976859
# Average loss at step 84000: 2.825565
# Average loss at step 86000: 2.924400
# Average loss at step 88000: 2.947935
# Average loss at step 90000: 2.933542
# Nearest to up: off, down, out, frightening, back, together, kis, ceti,
# Nearest to between: with, through, among, into, over, hornet, across, representing,
# Nearest to b: d, meaningful, cdot, deprogrammers, remix, cleanliness, lyapunov, abnormal,
# Nearest to history: origins, philosophy, concept, museum, origin, dominating, bangladeshis, nature,
# Nearest to two: three, four, five, leaguers, juliana, lockyer, companionship, six,
# Nearest to war: wars, bottlenecks, heritage, attacks, tdi, am, kann, martina,
# Nearest to during: throughout, after, in, since, despite, before, until, at,
# Nearest to but: however, although, than, and, though, until, which, monotheistic,
# Nearest to his: her, their, its, my, your, the, alkalis, our,
# Nearest to these: many, various, multiple, several, certain, some, different, numerous,
# Nearest to than: but, or, prescriptions, jodie, strives, executables, moveable, lulach,
# Nearest to one: hopper, cyclades, manchus, fenrir, highschool, alludes, cet, connie,
# Nearest to use: because, sense, version, purpose, speak, usage, share, consist,
# Nearest to that: which, if, however, luminiferous, when, where, lorne, alford,
# Nearest to can: may, could, must, cannot, would, should, might, will,
# Nearest to th: nd, nineteenth, twentieth, rd, st, nine, psilocybin, unimaginable,
# Average loss at step 92000: 2.832525
# Average loss at step 94000: 2.837100
# Average loss at step 96000: 2.891265
# Average loss at step 98000: 2.932365
# Average loss at step 100000: 2.844237
# Nearest to up: off, out, together, surfaces, kis, down, preferring, unspecified,
# Nearest to between: with, within, hornet, among, pagerank, therefore, controls, across,
# Nearest to b: d, deprogrammers, r, writer, assembl, onerous, lyapunov, transposed,
# Nearest to history: list, origins, concept, origin, life, philosophy, because, development,
# Nearest to two: three, seven, five, zero, four, helm, click, nitride,
# Nearest to war: wars, bottlenecks, attacks, conflict, martina, tdi, heritage, expatriate,
# Nearest to during: throughout, despite, in, after, since, before, following, over,
# Nearest to but: however, though, although, and, than, cryopreservation, invisibility, nearly,
# Nearest to his: her, their, its, your, my, the, our, whose,
# Nearest to these: multiple, numerous, various, they, which, clg, some, certain,
# Nearest to than: but, executables, prescriptions, unlike, lulach, overstated, alicia, moveable,
# Nearest to one: cryptozoologists, elisabetta, keillor, camping, petersburg, thulsa, kv, ooze,
# Nearest to use: share, opec, usage, help, ascertain, sense, spelling, used,
# Nearest to that: which, however, what, where, this, when, steamers, bsod,
# Nearest to can: could, may, cannot, must, should, would, will, might,
# Nearest to th: nd, nineteenth, twentieth, st, third, rd, sixth, f,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
