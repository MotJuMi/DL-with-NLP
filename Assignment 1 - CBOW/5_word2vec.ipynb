# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5235, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # Algorithmically, these models are similar, except that CBOW predicts center words from
        # context words, while the skip-gram does the inverse and predicts source context-words from
        # the center words. 
        # Thus we just need to swap batch_labels and batch_data in the line below to get the other model 
        # (skip-gram -> CBOW).
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        # Change shape of the arrays
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-11-4aa55ae93a88>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.951973
# Nearest to but: billed, antithetical, blonde, patron, minicomputers, jornal, squeeze, pitchfork,
# Nearest to new: calendar, servant, sabah, slave, healthcare, drivetrain, ash, sent,
# Nearest to states: voroshilov, formulaic, jigs, dangers, prophecies, dunes, subtracting, grading,
# Nearest to and: rabbits, lib, mayall, jonson, holds, somatic, apokryphen, tunes,
# Nearest to are: liaison, insulting, portage, snowflakes, reaches, reserve, roam, vyacheslav,
# Nearest to had: rays, sybase, waxing, motel, chernobyl, chalmers, discursive, applauded,
# Nearest to as: miao, coefficient, ineffable, restarted, hardback, hamburger, prerogatives, panic,
# Nearest to d: fuels, aura, residing, hydrogen, equine, endogamous, schopenhauer, wrecks,
# Nearest to there: pane, xe, stalk, gunboats, repeater, delaware, oscillators, culloden,
# Nearest to called: cumbria, kobe, heroically, born, packages, brewery, discrimination, fenian,
# Nearest to th: kin, latterly, ntsc, vikings, luck, biarritz, conjecture, muscles,
# Nearest to can: redefine, biloxi, noonan, hurry, recluse, cesare, trax, rammed,
# Nearest to to: judd, harvest, parcels, guitarists, arjuna, utilize, gly, zebulun,
# Nearest to while: conservancy, rewarding, skeletons, bulging, prophesied, sakhalin, boyz, dividing,
# Nearest to UNK: gao, communion, chance, hmong, kramer, lacking, constellation, slidell,
# Nearest to war: tourism, psychedelic, compatriots, sleepy, ronstadt, autonomy, mansfield, soares,
# Average loss at step 2000: 4.370065
# Average loss at step 4000: 3.858582
# Average loss at step 6000: 3.784325
# Average loss at step 8000: 3.653559
# Average loss at step 10000: 3.677848
# Nearest to but: derives, among, saturated, and, however, memorabilia, it, was,
# Nearest to new: servant, supercomputing, luang, sabah, tm, courtenay, radioisotope, major,
# Nearest to states: buying, voroshilov, subtracting, picchi, avars, packing, uvular, knocks,
# Nearest to and: or, for, hg, headlining, but, s, of, gamete,
# Nearest to are: were, is, be, have, claris, was, thereabouts, do,
# Nearest to had: has, have, was, adb, marginalized, wrote, aglaulus, shiite,
# Nearest to as: donnie, wishbone, by, with, substitutes, using, moth, widen,
# Nearest to d: b, aura, equine, perrault, lindsey, hydrogen, grasses, schopenhauer,
# Nearest to there: it, xe, legal, ecc, they, he, pane, stalk,
# Nearest to called: cumbria, brewery, sylvia, rib, fayyum, nss, made, born,
# Nearest to th: kin, bake, ntsc, axum, vikings, luck, biarritz, six,
# Nearest to can: will, would, could, may, alembert, rabbinic, fries, to,
# Nearest to to: would, not, arjuna, may, can, gly, for, stumbling,
# Nearest to while: after, prophesied, rewarding, with, orie, bulging, sequestered, straightforwardly,
# Nearest to UNK: provost, drava, coups, shines, configure, fac, h, kia,
# Nearest to war: googol, autonomy, psychedelic, genre, compatriots, mystical, annunzio, mansfield,
# Average loss at step 12000: 3.593445
# Average loss at step 14000: 3.511804
# Average loss at step 16000: 3.430644
# Average loss at step 18000: 3.510161
# Average loss at step 20000: 3.533300
# Nearest to but: and, however, although, though, since, that, forked, is,
# Nearest to new: servant, courtenay, luang, supercomputing, dafoe, sabah, minor, bingham,
# Nearest to states: buying, subtracting, picchi, uvular, packing, voroshilov, colossus, waxing,
# Nearest to and: or, but, who, which, from, of, to, while,
# Nearest to are: were, have, is, thereabouts, bbb, claris, other, include,
# Nearest to had: has, have, was, were, having, eliyahu, consume, wrote,
# Nearest to as: donnie, using, and, very, guessed, broadway, wakes, when,
# Nearest to d: b, publicised, chanting, perrault, depressive, dps, aura, wounded,
# Nearest to there: it, they, he, often, no, dissociate, stalk, xe,
# Nearest to called: nss, cumbria, fayyum, uniform, brewery, joker, sylvia, rib,
# Nearest to th: kin, bake, axum, bodmin, ntsc, pages, biarritz, dissociate,
# Nearest to can: will, would, may, could, must, should, cannot, alembert,
# Nearest to to: from, gly, not, for, and, will, suffered, may,
# Nearest to while: with, after, when, but, and, abolishes, prophesied, furthermore,
# Nearest to UNK: newsgroup, plaques, satchmo, patrilineal, salute, invented, panyu, de,
# Nearest to war: symbols, compatriots, elbow, autonomy, advert, dillinger, gaku, sleepy,
# Average loss at step 22000: 3.497354
# Average loss at step 24000: 3.477569
# Average loss at step 26000: 3.513999
# Average loss at step 28000: 3.450953
# Average loss at step 30000: 3.526156
# Nearest to but: however, although, though, which, and, where, while, that,
# Nearest to new: major, safest, recording, geodesic, courtenay, bingham, luang, hypnotized,
# Nearest to states: buying, subtracting, picchi, voroshilov, uvular, nations, packing, waxing,
# Nearest to and: or, premiers, in, but, ladder, undefined, barbarous, sportswriter,
# Nearest to are: were, have, is, include, while, thereabouts, voles, assume,
# Nearest to had: has, have, was, were, having, never, gave, eliyahu,
# Nearest to as: donnie, using, birger, by, groom, moth, nationalist, when,
# Nearest to d: b, fingerings, chanting, perrault, primitivism, betraying, trance, publicised,
# Nearest to there: they, it, he, now, often, usually, animalium, no,
# Nearest to called: fayyum, aarhus, cumbria, brewery, joker, wrap, plateau, separately,
# Nearest to th: kin, bake, bodmin, dissociate, zero, six, pages, afrique,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to to: can, may, thirdly, would, purport, prometheus, guitarists, lopes,
# Nearest to while: when, although, but, are, expatriates, furthermore, were, mazzola,
# Nearest to UNK: posen, pok, halliday, h, practicing, et, banquets, pulmonic,
# Nearest to war: compatriots, autonomy, sleepy, symbols, elbow, ronstadt, mansfield, annunzio,
# Average loss at step 32000: 3.478117
# Average loss at step 34000: 3.497113
# Average loss at step 36000: 3.384150
# Average loss at step 38000: 3.363543
# Average loss at step 40000: 3.449987
# Nearest to but: however, although, though, and, where, while, because, mrnas,
# Nearest to new: modern, safest, recording, hypnotized, major, harpers, braces, coups,
# Nearest to states: kingdom, subtracting, nations, buying, packing, picchi, zealand, waxing,
# Nearest to and: or, but, von, including, where, nik, in, like,
# Nearest to are: were, is, have, include, be, assume, pomona, piast,
# Nearest to had: has, have, was, were, having, since, never, been,
# Nearest to as: donnie, ramgoolam, tactile, downloaded, coefficient, ostrich, annette, oc,
# Nearest to d: b, c, n, fingerings, chanting, illustrating, f, donald,
# Nearest to there: they, it, now, usually, he, often, which, still,
# Nearest to called: fayyum, cumbria, cma, supplanted, nss, halliday, brewery, ym,
# Nearest to th: kin, bc, bodmin, bake, afrique, dissociate, pulverized, nd,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to to: will, would, prometheus, stumbling, blackadder, dislikes, purport, analytic,
# Nearest to while: when, although, after, where, but, are, unomig, furthermore,
# Nearest to UNK: merrimack, profess, peripheral, whales, st, o, battuta, vii,
# Nearest to war: symbols, compatriots, elbow, fermenting, autonomy, dillinger, gaku, googol,
# Average loss at step 42000: 3.428005
# Average loss at step 44000: 3.450810
# Average loss at step 46000: 3.425368
# Average loss at step 48000: 3.372283
# Average loss at step 50000: 3.382034
# Nearest to but: however, although, though, when, and, where, while, since,
# Nearest to new: braces, modern, tough, brent, personal, argento, courtenay, second,
# Nearest to states: kingdom, nations, subtracting, buying, packing, waxing, elven, zealand,
# Nearest to and: or, but, than, of, hg, while, hetzel, tillman,
# Nearest to are: were, is, have, include, assume, be, these, bartholomew,
# Nearest to had: has, have, was, were, finally, having, since, never,
# Nearest to as: donnie, brainwashed, khagan, janeiro, moth, stanislavski, by, ramgoolam,
# Nearest to d: b, c, f, n, donald, illustrating, r, ons,
# Nearest to there: they, it, he, now, this, usually, still, we,
# Nearest to called: fayyum, brewery, von, named, halliday, wrap, saves, nss,
# Nearest to th: kin, bc, pulverized, afrique, one, bodmin, bake, committing,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to to: lopes, not, can, purport, may, gly, maximization, gloss,
# Nearest to while: when, although, where, after, if, however, but, and,
# Nearest to UNK: m, nazionale, spacing, h, banquets, n, p, c,
# Nearest to war: symbols, compatriots, boar, googol, compliant, elbow, dillinger, fermenting,
# Average loss at step 52000: 3.446990
# Average loss at step 54000: 3.434784
# Average loss at step 56000: 3.418482
# Average loss at step 58000: 3.399824
# Average loss at step 60000: 3.392622
# Nearest to but: however, although, and, since, though, see, while, when,
# Nearest to new: brent, modern, particular, tough, braces, recording, synapse, summand,
# Nearest to states: kingdom, nations, companies, countries, subtracting, packing, thunderbirds, buying,
# Nearest to and: or, but, salaam, in, including, while, rower, pacific,
# Nearest to are: were, is, have, include, although, thereabouts, including, interceptions,
# Nearest to had: has, have, was, were, having, been, never, finally,
# Nearest to as: donnie, selectivity, najibullah, alkaloids, ramgoolam, nims, fissile, heroine,
# Nearest to d: b, c, n, lysosome, r, ons, f, donald,
# Nearest to there: they, it, he, now, this, we, still, often,
# Nearest to called: used, known, named, nss, ced, orville, subversive, supplanted,
# Nearest to th: kin, bc, six, pulverized, afrique, seven, four, five,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to to: lopes, would, toward, thirdly, for, dislikes, analytic, purport,
# Nearest to while: although, when, after, where, though, were, and, sahel,
# Nearest to UNK: http, lichen, references, wondered, catamaran, et, w, adjutant,
# Nearest to war: boar, symbols, googol, compatriots, gaku, elbow, compliant, sleepy,
# Average loss at step 62000: 3.154513
# Average loss at step 64000: 3.346815
# Average loss at step 66000: 3.405205
# Average loss at step 68000: 3.377174
# Average loss at step 70000: 3.373526
# Nearest to but: however, although, while, though, and, that, since, see,
# Nearest to new: tough, numeric, brent, modern, nanotube, synapse, braces, particular,
# Nearest to states: kingdom, nations, countries, subtracting, picchi, waxing, pilgrimage, namibia,
# Nearest to and: or, but, while, mjw, s, including, when, perforce,
# Nearest to are: were, include, is, although, these, brazen, have, bartholomew,
# Nearest to had: have, has, were, was, having, began, since, attempted,
# Nearest to as: using, slime, betters, tactile, adaptable, brainwashed, groom, analyzes,
# Nearest to d: b, lysosome, r, donald, ons, l, p, k,
# Nearest to there: they, it, he, we, now, usually, still, this,
# Nearest to called: named, meditating, brewery, fayyum, overwhelmingly, invincible, wrap, considered,
# Nearest to th: bc, kin, afrique, pulverized, seven, seventeenth, rd, committing,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to to: would, can, apoplexy, towards, nchen, must, for, parson,
# Nearest to while: although, when, though, but, including, where, if, after,
# Nearest to UNK: sir, sufficiency, l, k, freda, watercolors, cancelling, et,
# Nearest to war: compliant, boar, compatriots, sleepy, advert, googol, elbow, gulag,
# Average loss at step 72000: 3.361715
# Average loss at step 74000: 3.376963
# Average loss at step 76000: 3.280428
# Average loss at step 78000: 3.352277
# Average loss at step 80000: 3.393433
# Nearest to but: however, although, while, though, and, pomona, brow, see,
# Nearest to new: brent, numeric, safest, tough, summand, synapse, repellent, tm,
# Nearest to states: kingdom, nations, countries, state, waxing, ishiro, elven, packing,
# Nearest to and: or, but, including, strassman, while, peabody, sportswriter, stacking,
# Nearest to are: were, is, although, include, have, bartholomew, while, including,
# Nearest to had: have, has, was, were, having, eliyahu, never, began,
# Nearest to as: groom, ulema, brainwashed, noticable, tactile, erie, formerly, for,
# Nearest to d: b, ons, j, p, m, perrault, playa, norah,
# Nearest to there: they, he, it, we, she, still, now, often,
# Nearest to called: named, known, used, considered, brewery, redfern, playful, desalination,
# Nearest to th: bc, kin, pulverized, seventeenth, afrique, rd, committing, seven,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to to: would, lopes, will, can, must, toward, for, prompt,
# Nearest to while: although, but, though, when, after, unomig, including, where,
# Nearest to UNK: shines, l, j, basel, curran, ito, sir, unofficial,
# Nearest to war: boar, compliant, wars, mise, symbols, verse, spoil, dillinger,
# Average loss at step 82000: 3.413476
# Average loss at step 84000: 3.402234
# Average loss at step 86000: 3.379542
# Average loss at step 88000: 3.358091
# Average loss at step 90000: 3.362499
# Nearest to but: however, and, although, though, while, pomona, which, or,
# Nearest to new: particular, brent, tough, repellent, different, tm, ignorant, safest,
# Nearest to states: kingdom, nations, countries, companies, tleilaxu, waxing, state, subtracting,
# Nearest to and: or, but, including, antagonism, mjw, while, tillman, shaughnessy,
# Nearest to are: were, is, include, have, these, although, bartholomew, contain,
# Nearest to had: has, have, were, was, having, eliyahu, began, never,
# Nearest to as: noticable, donnie, lees, moth, mechanistic, tactile, amending, slime,
# Nearest to d: b, p, walker, norah, playa, m, f, veto,
# Nearest to there: they, it, he, we, she, now, usually, sometimes,
# Nearest to called: known, named, used, considered, overwhelmingly, referred, neoliberal, orville,
# Nearest to th: bc, one, pulverized, kin, afrique, rd, seventeenth, six,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to to: would, lopes, can, could, will, imt, dislikes, prompt,
# Nearest to while: although, when, though, before, but, after, unomig, where,
# Nearest to UNK: jan, http, references, catamaran, fusion, nr, comp, erfurt,
# Nearest to war: wars, boar, averted, mise, googol, compliant, rewriting, dft,
# Average loss at step 92000: 3.369346
# Average loss at step 94000: 3.271808
# Average loss at step 96000: 3.341994
# Average loss at step 98000: 3.244027
# Average loss at step 100000: 3.360736
# Nearest to but: however, although, though, and, while, which, where, when,
# Nearest to new: tough, safest, different, lithographic, braces, numeric, particular, previous,
# Nearest to states: kingdom, nations, countries, companies, tleilaxu, zealand, arab, waxing,
# Nearest to and: or, but, while, including, accountable, however, principate, rower,
# Nearest to are: were, have, although, is, those, bartholomew, while, these,
# Nearest to had: has, have, was, were, having, began, since, never,
# Nearest to as: when, donnie, became, noticable, adaptable, before, betters, tactile,
# Nearest to d: b, perrault, o, wounded, weidman, primitivism, anthologized, c,
# Nearest to there: they, we, it, he, now, she, often, generally,
# Nearest to called: named, known, overwhelmingly, considered, referred, fayyum, termed, brewery,
# Nearest to th: bc, pulverized, rd, kin, one, afrique, seventeenth, committing,
# Nearest to can: could, may, must, will, would, should, might, cannot,
# Nearest to to: will, would, could, and, lopes, should, dislikes, can,
# Nearest to while: although, when, though, but, after, before, and, unomig,
# Nearest to UNK: miller, jackson, earned, by, decimus, stewart, allen, williams,
# Nearest to war: wars, boar, compliant, averted, dft, googol, conflict, spoil,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
